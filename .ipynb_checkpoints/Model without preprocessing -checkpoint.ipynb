# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# Загрузим и проанализируем данные

# %%
data = pd.read_csv('RDC_samples/train.csv')

# %%
data.head()
# Out:
#    No.      Time       Source  Destination Protocol  Length  \
# 0    1  0.000000  10.0.151.43   10.0.16.14      TCP    1026
# 1    2  0.000004  10.0.151.43   10.0.16.14      TCP    1026
# 2    3  0.000019    10.0.4.66  10.0.17.129      TCP      70
# 3    4  0.000021    10.0.4.66  10.0.17.129      TCP      70
# 4    5  0.000055   10.0.16.14  10.0.151.43      TCP      64
#
#                                                 Info
# 0  8000  >  63774 [PSH, ACK] Seq=1 Ack=1 Win=229 ...
# 1  [TCP Retransmission] 8000  >  63774 [PSH, ACK]...
# 2  445  >  36384 [ACK] Seq=1 Ack=1 Win=2573 Len=0...
# 3  [TCP Dup ACK 3#1] 445  >  36384 [ACK] Seq=1 Ac...
# 4    63774  >  8000 [ACK] Seq=1 Ack=1 Win=4096 Len=0

# %%
data.Protocol.count()
# Out:
# 269306

# %%
data.Protocol.loc[data.Protocol == 'TCP'].count()
# Out:
# 269306

# %%
data.Info.apply(lambda x: x.find('Win') != -1).count()
# Out:
# 269306

# %% [markdown]
# Распарсим колонку Info и оцифруем Ip адреса

# %%
def parse_data(par_list):
    par_list = par_list.split()

    if not par_list[0].isdigit():
        counter = 0
        while not par_list[counter].isdigit():
            counter+=1        
        par_list = par_list[counter:]

    source_port = int(par_list[0])
    destination_port = int(par_list[2])
    windows_size_val = 0

    for it in par_list:
        if it.find('Win')!=-1:
            windows_size_val = int(it[4:])
            break
    return [source_port, destination_port, windows_size_val]

# %%
def data_init(file_name='train.csv'):
    data = pd.read_csv('RDC_samples/'+file_name)
    data['params'] = data.Info.apply(parse_data)
    data[['source_port', 'destination_port', 'windows_size_val']] = pd.DataFrame(data.params.tolist(), index=data.index)
    data = data.drop(columns=['params', 'Info', 'Protocol', 'Time', 'No.'])
    data.Source = data.Source.apply(lambda x: int(x.replace('.', '')) if x.replace('.', '').isdigit() else None)
    data.Destination = data.Destination.apply(lambda x: int(x.replace('.', '')) if x.replace('.', '').isdigit() else None)
    return data

# %%
data = data_init('train.csv')

# %%
data.head()
# Out:
#      Source  Destination  Length  source_port  destination_port  \
# 0  10015143      1001614    1026         8000             63774
# 1  10015143      1001614    1026         8000             63774
# 2    100466     10017129      70          445             36384
# 3    100466     10017129      70          445             36384
# 4   1001614     10015143      64        63774              8000
#
#    windows_size_val
# 0               229
# 1               229
# 2              2573
# 3              2573
# 4              4096

# %% [markdown]
# Посмотрим сколько уникальных элементов и построим гистограммы, чтобы понять, какие элементы считать аномалиями

# %%
data.nunique()
# Out:
# Source               31
# Destination          40
# Length              497
# source_port         162
# destination_port     90
# windows_size_val    607
# dtype: int64

# %%
data.hist(figsize=(10, 9))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# array([[<AxesSubplot:title={'center':'Source'}>,
#         <AxesSubplot:title={'center':'Destination'}>],
#        [<AxesSubplot:title={'center':'Length'}>,
#         <AxesSubplot:title={'center':'source_port'}>],
#        [<AxesSubplot:title={'center':'destination_port'}>,
#         <AxesSubplot:title={'center':'windows_size_val'}>]], dtype=object)

# %%
plt.figure()
data.groupby('Source').Destination.count().rename({'Destination':'count'}).plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Source'>

# %% [markdown]
# Заметим, что практически все запросы приходили с 2-ух ресурсов, поэтому избавимся от всех остальных элеметов, чтобы не переобучить модель на выбросах

# %%
fil_sources = data.groupby('Source').Destination.count().sort_values(ascending=False)[:2].index

# %%
fil_sources
# Out:
# Int64Index([10017129, 100466], dtype='int64', name='Source')

# %%
data = data.loc[(data.Source == fil_sources[0]) | (data.Source == fil_sources[1])]

# %%
data.groupby('Source').Destination.count().sort_values(ascending=False)
# Out:
# Source
# 10017129    210250
# 100466       45116
# Name: Destination, dtype: int64

# %%
data.hist(figsize=(9,9))
# Out:
# <img src="data:image/png;base64,..." width="900">
# array([[<AxesSubplot:title={'center':'Source'}>,
#         <AxesSubplot:title={'center':'Destination'}>],
#        [<AxesSubplot:title={'center':'Length'}>,
#         <AxesSubplot:title={'center':'source_port'}>],
#        [<AxesSubplot:title={'center':'destination_port'}>,
#         <AxesSubplot:title={'center':'windows_size_val'}>]], dtype=object)

# %% [markdown]
# Заметим, что убрав необычные источники данных, на остальных графиках также практически изчезли аномалии
#
# Создадим полносвязную нейронную сеть, задачей которой будет на выходе давать результат схожий с тем, что был на входе, тогда при наличии аномалий, нейронная сеть будет давать большую ошибку, что можно будет отследить

# %%
import torch
from torch import nn

# %%
X = torch.FloatTensor(np.asarray(data))

# %%
train_data_size = int(0.8*X.shape[0])
X_train, X_val = X[:train_data_size], X[train_data_size:]

# %%
X_train.shape
# Out:
# torch.Size([215444, 6])

# %%
X_val.shape
# Out:
# torch.Size([53862, 6])

# %%
features_count = X_train.shape[1]
rows = X_train.shape[0]
learning_rate = 1e-3
batch_size = 700
epochs = 5

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
model = nn.Sequential(
    nn.Linear(features_count, 32),
    nn.ReLU(),
    nn.Linear(32,48),
    nn.ReLU(),
    nn.Linear(48,64),
    nn.ReLU(),
    nn.Linear(64,32),
    nn.ReLU(),
    nn.Linear(32,features_count)
)
model.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=6, out_features=32, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=32, out_features=48, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=48, out_features=64, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=64, out_features=32, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=32, out_features=6, bias=True)
# )

# %%
criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
loss_history = []
for epoch in range(epochs):
    for b_num in range(rows//batch_size):
        batch_X = X_train[b_num*batch_size:(b_num+1)*batch_size]
        batch_X = batch_X.to(device)
        pred = model.forward(batch_X)
        loss = criterion(pred, batch_X)
        loss_history.append(loss.item())
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(loss_history[-1])
# Out:
# 30144.064453125
# 27260.58984375
# 40866.19140625
# 37049.25
# 27651.134765625

# %%
plt.figure()
plt.plot(loss_history)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
loss_history[-1]
# Out:
# 27651.134765625

# %% [markdown]
# Осталась достаточно большая ошибка, но при этом она стабильная, то есть если в данных будут аномалии, то ошибка, предположительно, будет гораздо больше

# %% [markdown]
# Сделаем прямой проход на валидационных данных и найдем l1 метрику для каждого элемента

# %%
def predict(X_to_pred):
    with torch.no_grad():
        rows = X_to_pred.shape[0]
        predictions = np.array([[0]*features_count])
        for b_num in range(rows//batch_size):
            batch_X = X_to_pred[b_num*batch_size:(b_num+1)*batch_size]
            pred = np.asarray(model.forward(batch_X))
            predictions = np.vstack((predictions, pred))
        batch_X = X_to_pred[(rows//batch_size)*batch_size:]
        pred = np.asarray(model.forward(batch_X))
        predictions = np.vstack((predictions, pred))
    return predictions[1:]

# %%
model.cpu()
preds = predict(X_val)
preds
# Out:
# array([[ 9.89114375e+04,  1.00386560e+07, -3.63371191e+03,
#         -1.31043662e+04,  4.45131094e+04,  6.37643616e+02],
#        [ 9.89114375e+04,  1.00386560e+07, -3.63371191e+03,
#         -1.31043662e+04,  4.45131094e+04,  6.37643616e+02],
#        [ 9.87401250e+04,  1.00367560e+07, -3.62421191e+03,
#         -1.31321787e+04,  4.45097344e+04,  6.40581116e+02],
#        ...,
#        [ 9.85929300e+06,  7.57521250e+04, -1.04373682e+04,
#          3.06654141e+04, -2.50317012e+04, -1.07395470e+02],
#        [ 9.85929300e+06,  7.57521250e+04, -1.04373682e+04,
#          3.06654141e+04, -2.50317012e+04, -1.07395470e+02],
#        [ 9.85966200e+06,  7.57511250e+04, -1.04389932e+04,
#          3.06564141e+04, -2.50342012e+04, -1.11356407e+02]])

# %%
preds.shape
# Out:
# (53862, 6)

# %%
X_val_tmp = np.asarray(X_val)
losses = np.sum(np.abs(X_val_tmp - preds),axis=1)
print(losses.shape)
# Out:
# (53862,)

# %%
plt.figure()
plt.plot(losses)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
losses = pd.Series(losses)
losses.loc[losses > 0.5*1e8]
# Out:
# 16615    2.457650e+08
# 16616    2.457650e+08
# 34073    9.520628e+07
# 34074    9.520628e+07
# dtype: float64

# %% [markdown]
# Нашли индексы элементов из первоначального датасета которые модель посчитала аномалиями
# Заметим, что на обучающих данных ошибка была не такая стабильная как на валидационных, но при этом и аномалий заметно не было, потому что на тестовых данных считалась средняя ошибка на батче.
#
# Проведем аналогичный анализ на первом тестовом датасете

# %%
test_data_1 = data_init('test_1.csv')

# %%
test_data_1.head()
# Out:
#     Source  Destination  Length  source_port  destination_port  \
# 0  1004245     10016152    1518         3128             62408
# 1  1004245     10016152    2978         3128             62408
# 2  1004245     10016152    2978         3128             62408
# 3  1004245     10016152    2978         3128             62408
# 4  1004245     10016152    2973         3128             62408
#
#    windows_size_val
# 0               513
# 1               513
# 2               513
# 3               513
# 4               513

# %%
test_data_1.isnull().sum()
# Out:
# Source              0
# Destination         0
# Length              0
# source_port         0
# destination_port    0
# windows_size_val    0
# dtype: int64

# %%
X_test = torch.FloatTensor(np.asarray(test_data_1))
X_test.shape
# Out:
# torch.Size([268378, 6])

# %%
preds = predict(X_test)
X_test_tmp = np.asarray(X_test)
losses = np.sum(np.abs(X_test_tmp - preds),axis=1)
print(losses.shape)

# %%
plt.figure()
plt.plot(losses)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
losses = pd.Series(losses)
losses = losses.loc[losses > 0.5 * 1e9]

# %%
losses
# Out:
# 6618      1.436555e+09
# 6619      1.436555e+09
# 9190      6.958167e+08
# 9191      6.958167e+08
# 29443     1.436555e+09
# 29444     1.436555e+09
# 58902     6.958167e+08
# 58903     6.958167e+08
# 77444     1.436555e+09
# 77445     1.436555e+09
# 93418     2.280117e+09
# 93419     2.280117e+09
# 117922    2.280117e+09
# 117923    2.280117e+09
# 136857    1.436555e+09
# 136858    1.436555e+09
# 158076    6.958167e+08
# 158077    6.958167e+08
# 181706    1.436555e+09
# 181707    1.436555e+09
# 185724    1.436555e+09
# 185725    1.436555e+09
# 207565    1.436555e+09
# 207566    1.436555e+09
# 252778    1.436555e+09
# 252779    1.436555e+09
# dtype: float64

# %%
test_data_1_abnormal = test_data_1.loc[losses.index]

# %%
test_data_1_abnormal
# Out:
#           Source   Destination  Length  source_port  destination_port  \
# 6618    10016139   82202185148      70        50624               443
# 6619    10016139   82202185148      70        50624               443
# 9190    10016139   40127240158      70        50623               443
# 9191    10016139   40127240158      70        50623               443
# 29443   10016139   82202185148      70        50624               443
# 29444   10016139   82202185148      70        50624               443
# 58902   10016139   40127240158      70        50623               443
# 58903   10016139   40127240158      70        50623               443
# 77444   10016139   82202185148      70        50624               443
# 77445   10016139   82202185148      70        50624               443
# 93418   10016139  130117190228      70        50625               443
# 93419   10016139  130117190228      70        50625               443
# 117922  10016139  130117190228      70        50625               443
# 117923  10016139  130117190228      70        50625               443
# 136857  10016139   82202184184      70        50626               443
# 136858  10016139   82202184184      70        50626               443
# 158076  10016139   40127240158      70        50623               443
# 158077  10016139   40127240158      70        50623               443
# 181706  10016139   82202185146      70        50628               443
# 181707  10016139   82202185146      70        50628               443
# 185724  10016139   82202184193      70        50629               443
# 185725  10016139   82202184193      70        50629               443
# 207565  10016139   82202184193      70        50629               443
# 207566  10016139   82202184193      70        50629               443
# 252778  10016139   82202184193      70        50629               443
# 252779  10016139   82202184193      70        50629               443
#
#         windows_size_val
# 6618               64240
# 6619               64240
# 9190               64240
# 9191               64240
# 29443              64240
# 29444              64240
# 58902              64240
# 58903              64240
# 77444              64240
# 77445              64240
# 93418              64240
# 93419              64240
# 117922             64240
# 117923             64240
# 136857             64240
# 136858             64240
# 158076             64240
# 158077             64240
# 181706             64240
# 181707             64240
# 185724             64240
# 185725             64240
# 207565             64240
# 207566             64240
# 252778             64240
# 252779             64240

# %% [markdown]
# Проанализируем второй тестовый датасет

# %%
test_data_2 = data_init('test_2.csv')

# %%
test_data_2.isnull().sum()
# Out:
# Source              50
# Destination         50
# Length               0
# source_port          0
# destination_port     0
# windows_size_val     0
# dtype: int64

# %%
test_data_2 = test_data_2.dropna()

# %%
test_data_2.isnull().sum()
# Out:
# Source              0
# Destination         0
# Length              0
# source_port         0
# destination_port    0
# windows_size_val    0
# dtype: int64

# %%
X_test = torch.FloatTensor(np.asarray(test_data_2))
preds = predict(X_test)
X_test_tmp = np.asarray(X_test)
losses = np.sum(np.abs(X_test_tmp - preds),axis=1)
plt.figure()
plt.plot(losses)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
losses = pd.Series(losses)
losses = losses.loc[losses > 0.5 * 1e9]

# %%
test_data_2_abnormal = test_data_2.loc[losses.index]
test_data_2_abnormal.head()
# Out:
#            Source   Destination  Length  source_port  destination_port  \
# 15     10016140.0  8.220218e+10      70        55002               443
# 7212   10016140.0  8.220218e+10      70        55003               443
# 7213   10016140.0  8.220218e+10      70        55003               443
# 13390  10016140.0  8.220218e+10      70        55003               443
# 13391  10016140.0  8.220218e+10      70        55003               443
#
#        windows_size_val
# 15                64240
# 7212              64240
# 7213              64240
# 13390             64240
# 13391             64240

# %% [markdown]
# Проанализируем третий тестовый датасет

# %%
test_data_3 = data_init('test_3.csv')

# %%
test_data_3.isnull().sum()
# Out:
# Source              0
# Destination         0
# Length              0
# source_port         0
# destination_port    0
# windows_size_val    0
# dtype: int64

# %%
X_test = torch.FloatTensor(np.asarray(test_data_3))
preds = predict(X_test)
X_test_tmp = np.asarray(X_test)
losses = np.sum(np.abs(X_test_tmp - preds),axis=1)
plt.figure()
plt.plot(losses)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
losses = pd.Series(losses)
losses = losses.loc[losses > 0.5 * 1e7]
losses.shape
# Out:
# (8,)

# %%
test_data_3_abnormal = test_data_3.loc[losses.index]
test_data_3_abnormal.head()
# Out:
#           Source  Destination  Length  source_port  destination_port  \
# 11488   10108115    100109143      70        57986             13000
# 11489   10108115    100109143      70        57986             13000
# 41145   10108122    100112228      70        63396             13000
# 41146   10108122    100112228      70        63396             13000
# 52750  101081134    100112228      70        58743             13000
#
#        windows_size_val
# 11488             65535
# 11489             65535
# 41145             65535
# 41146             65535
# 52750             65535
